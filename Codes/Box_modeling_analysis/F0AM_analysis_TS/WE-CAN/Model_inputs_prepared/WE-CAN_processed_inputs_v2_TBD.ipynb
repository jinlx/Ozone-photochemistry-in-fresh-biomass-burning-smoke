# %% [markdown]
# #### 20220829, apply scale factor for corresonponding scripts.
# - Propanal_C3H6O_PTR         = ACETONE_C3H6O_PTR.*0.17;
# - Butanal_C4H8O_PTR          = MEK_C4H8O_PTR.*0.01;
# - 2_Methylpropanal_C4H8O_PTR = MEK_C4H8O_PTR.*0.14
# - 2_Methylbutanal_PTR        = 3_methyl_2_butanone_C5H10O_PTR.*0.04
# - Ethyl_benzene_C8H10_PTR = C8_AROMATICS_C8H10_PTR.*0.36;
# - mpXylenes_C8H10_PTR = C8_AROMATICS_C8H10_PTR.*0.46;
# - oXylene_C8H10_PTR = C8_AROMATICS_C8H10_PTR.*0.18;
# - acetic_acid_C2H4O2_PTR = acetic_acid_C2H4O2_PTR.*0.67;
# - apinene_C10H16_PTR = MONOTERPENES_C10H16_PTR.*0.33;
# - bpinene_C10H16_PTR = MONOTERPENES_C10H16_PTR.*0.21;
# - MVK_C4H6O_PTR = MACR_MVK_C4H6O_PTR.*0.60;
# - MACR_C4H6O_PTR = MACR_MVK_C4H6O_PTR.*0.28;
# - ACETONE_C3H6O_PTR = ACETONE_C3H6O_PTR.*0.83;
# - MEK_C4H8O_PTR = MEK_C4H8O_PTR.*0.85;
# - 2_Methylfuran_C5H6O_PTR = 2_METHYLFURAN_C5H6O_PTR.*0.84;
# - 3_Methylfuran_C5H6O_PTR = 2_METHYLFURAN_C5H6O_PTR.*0.16;
# - 5_METHYLFURFURAL_C6H6O2_PTR = 5_METHYLFURFURAL_C6H6O2_PTR.*0.5;
# - glycolaldehyde_C2H4O2_PTR = acetic_acid_C2H4O2_PTR.*0.33;
# - hydroxyacetone_C3H6O2_PTR = hydroxyacetone_C3H6O2_PTR.*0.51;
# - Methyl_acetate_C3H6O2_PTR = hydroxyacetone_C3H6O2_PTR.*0.35;
# - Ethyl_formate_C3H6O2_PTR = hydroxyacetone_C3H6O2_PTR.*0.14;
# - 2_Butenal_C4H6O_PTR = MACR_MVK_C4H6O_PTR.*0.13;
# - iBuONO2_TOGA = iBuONO2and2BuONO2_TOGA.*0.5;
# - nBuONO2_TOGA = iBuONO2and2BuONO2_TOGA.*0.5;
# - MBO_C5H10O_PTR = 3_methyl_2_butanone_C5H10O_PTR.*0.43;
# - 2_Pentanone_C5H10O_PTR = 3_methyl_2_butanone_C5H10O_PTR.*0.23;
# - 3_Pentanone_C5H10O_PTR = 3_methyl_2_butanone_C5H10O_PTR.*0.21;
# - Catechol_C6H6O2_PTR = 5_METHYLFURFURAL_C6H6O2_PTR.*0.5;
# - Hexanones_C6H12O_PTR = 3_HEXANONE_C6H12O_PTR.*0.53;
# - Hexanal_C6H12O_PTR = 3_HEXANONE_C6H12O_PTR.*0.47;
# - heptanal_C7H14O_PTR = heptanal_C7H14O_PTR.*0.63;
# - heptanone_C7H14O_PTR = heptanal_C7H14O_PTR.*0.37;

# %% [markdown]
# This dataset needs to wait for Wade's updates to be done.

# %%
import pandas as pd
import numpy as np
import scipy.io as sio

# %%
# obsolete for now
def fix_PTR_isomers(df_conc, smk_conc=False, bkg_conc=False):
    setting = 'smk_' if smk_conc else 'bkg_'
    # Step 1: create a new species list
    data = pd.DataFrame()  # Placeholder for `ranking`
    data = pd.concat([data, 
                      df_conc[setting + 'ACETONE_C3H6O_PTR']*0.17,
                      df_conc[setting + 'MEK_C4H8O_PTR']*0.01,
                      df_conc[setting + 'MEK_C4H8O_PTR']*0.14,
                      df_conc[setting + '3_methyl_2_butanone_C5H10O_PTR']*0.04,
                      df_conc[setting + 'C8_AROMATICS_C8H10_PTR']*0.36,
                      df_conc[setting + 'C8_AROMATICS_C8H10_PTR']*0.46,
                      df_conc[setting + 'C8_AROMATICS_C8H10_PTR']*0.18,
                      df_conc[setting + 'acetic_acid_C2H4O2_PTR']*0.67,
                      df_conc[setting + 'MONOTERPENES_C10H16_PTR']*0.33,
                      df_conc[setting + 'MONOTERPENES_C10H16_PTR']*0.21,
                      df_conc[setting + 'MACR_MVK_C4H6O_PTR']*0.60,
                      df_conc[setting + 'MACR_MVK_C4H6O_PTR']*0.28,
                      df_conc[setting + 'ACETONE_C3H6O_PTR']*0.83,
                      df_conc[setting + 'MEK_C4H8O_PTR']*0.85,
                      df_conc[setting + '2_METHYLFURAN_C5H6O_PTR']*0.84,
                      df_conc[setting + '2_METHYLFURAN_C5H6O_PTR']*0.16,
                      df_conc[setting + '5_METHYLFURFURAL_C6H6O2_PTR']*0.5,     
                      df_conc[setting + 'acetic_acid_C2H4O2_PTR']*0.33,
                      df_conc[setting + 'hydroxyacetone_C3H6O2_PTR']*0.51,
                      df_conc[setting + 'hydroxyacetone_C3H6O2_PTR']*0.35,
                      df_conc[setting + 'hydroxyacetone_C3H6O2_PTR']*0.14,
                      df_conc[setting + 'MACR_MVK_C4H6O_PTR']*0.13,
                      df_conc[setting + 'iBuONO2and2BuONO2_TOGA']*0.5,
                      df_conc[setting + 'iBuONO2and2BuONO2_TOGA']*0.5,
                      df_conc[setting + '3_methyl_2_butanone_C5H10O_PTR']*0.43,
                      df_conc[setting + '3_methyl_2_butanone_C5H10O_PTR']*0.23,
                      df_conc[setting + '3_methyl_2_butanone_C5H10O_PTR']*0.21,
                      df_conc[setting + '5_METHYLFURFURAL_C6H6O2_PTR']*0.5,
                      df_conc[setting + '3_HEXANONE_C6H12O_PTR']*0.53,
                      df_conc[setting + '3_HEXANONE_C6H12O_PTR']*0.47, 
                      df_conc[setting + 'heptanal_C7H14O_PTR']*0.63,
                      df_conc[setting + 'heptanal_C7H14O_PTR']*0.37],axis=1)
    # Step 2: rename these columns
    col_names = [setting + 'Propanal_C3H6O_PTR', setting + 'Butanal_C4H8O_PTR', setting + '2_Methylpropanal_C4H8O_PTR', setting + '2_Methylbutanal_PTR',
                 setting + 'Ethyl_benzene_C8H10_PTR', setting + 'mpXylenes_C8H10_PTR', setting + 'oXylene_C8H10_PTR',
                 setting + 'acetic_acid_C2H4O2_PTR',
                 setting + 'apinene_C10H16_PTR', setting + 'bpinene_C10H16_PTR', setting + 'MVK_C4H6O_PTR', setting + 'MACR_C4H6O_PTR',
                 setting + 'ACETONE_C3H6O_PTR', setting + 'MEK_C4H8O_PTR',
                 setting + '2_Methylfuran_C5H6O_PTR', setting + '3_Methylfuran_C5H6O_PTR', setting + '5_METHYLFURFURAL_C6H6O2_PTR',
                 setting + 'glycolaldehyde_C2H4O2_PTR',
                 setting + 'hydroxyacetone_C3H6O2_PTR',
                 setting + 'Methyl_acetate_C3H6O2_PTR',
                 setting + 'Ethyl_formate_C3H6O2_PTR',
                 setting + '2_Butenal_C4H6O_PTR',
                 setting + 'iBuONO2_TOGA',
                 setting + 'nBuONO2_TOGA',
                 setting + 'MBO_C5H10O_PTR',
                 setting + '2_Pentanone_C5H10O_PTR',
                 setting + '3_Pentanone_C5H10O_PTR',
                 setting + 'Catechol_C6H6O2_PTR',
                 setting + 'Hexanones_C6H12O_PTR',
                 setting + 'Hexanal_C6H12O_PTR',
                 setting + 'heptanal_C7H14O_PTR',
                 setting + 'heptanone_C7H14O_PTR']

    data.columns = col_names
    # Step 3; remove the old used columns
    old_columns = list(set([setting + 'ACETONE_C3H6O_PTR',
                   setting + 'MEK_C4H8O_PTR',
                   setting + 'MEK_C4H8O_PTR',
                   setting + '3_methyl_2_butanone_C5H10O_PTR',
                   setting + 'C8_AROMATICS_C8H10_PTR',
                   setting + 'C8_AROMATICS_C8H10_PTR',
                   setting + 'C8_AROMATICS_C8H10_PTR',
                   setting + 'acetic_acid_C2H4O2_PTR',
                   setting + 'MONOTERPENES_C10H16_PTR',
                   setting + 'MONOTERPENES_C10H16_PTR',
                   setting + 'MACR_MVK_C4H6O_PTR',
                   setting + 'MACR_MVK_C4H6O_PTR',
                   setting + 'ACETONE_C3H6O_PTR',
                   setting + 'MEK_C4H8O_PTR',
                   setting + '2_METHYLFURAN_C5H6O_PTR',
                   setting + '2_METHYLFURAN_C5H6O_PTR',
                   setting + '5_METHYLFURFURAL_C6H6O2_PTR',
                   setting + 'acetic_acid_C2H4O2_PTR',
                   setting + 'hydroxyacetone_C3H6O2_PTR',
                   setting + 'hydroxyacetone_C3H6O2_PTR',
                   setting + 'hydroxyacetone_C3H6O2_PTR',
                   setting + 'MACR_MVK_C4H6O_PTR',
                   setting + 'iBuONO2and2BuONO2_TOGA',
                   setting + 'iBuONO2and2BuONO2_TOGA',
                   setting + '3_methyl_2_butanone_C5H10O_PTR',
                   setting + '3_methyl_2_butanone_C5H10O_PTR',
                   setting + '3_methyl_2_butanone_C5H10O_PTR',
                   setting + '5_METHYLFURFURAL_C6H6O2_PTR',
                   setting + '3_HEXANONE_C6H12O_PTR',
                   setting + '3_HEXANONE_C6H12O_PTR',
                   setting + 'heptanal_C7H14O_PTR',
                   setting + 'heptanal_C7H14O_PTR']))
    df_conc = df_conc.drop(old_columns, axis = 1)
    
    # Step 4: concat those two together
    return pd.concat([df_conc, data], axis = 1)
def WECAN_process(df, Flight_ID, smk_conc=False, bkg_conc=False, nemr_conc=False, met_data=False):
    """
    Processes and saves WE-CAN flight data based on specified parameters.

    Args:
        df (DataFrame): The dataframe containing the WE-CAN dataset.
        Flight_ID (str): The flight ID to process data for.
        smk_conc (bool): If True, processes smoke concentration data.
        bkg_conc (bool): If True, processes background concentration data.
        nemr_conc (bool): If True, processes NEMR concentration data.
        met_data (bool): If True, processes meteorological data.

    Returns:
        DataFrame: Processed and sorted dataframe based on specified parameters.
    """
    if smk_conc == True:
        output = df[df['Flight_ID'] == Flight_ID][['Age_physical_avg_min'] + conc_smk_spec]
        name = 'smk_conc'
    elif bkg_conc == True:
        output = df[df['Flight_ID'] == Flight_ID][['Age_physical_avg_min'] + conc_bkg_spec]
        name = 'bkg_conc'
    elif nemr_conc == True:
        output = df[df['Flight_ID'] == Flight_ID][['Age_physical_avg_min'] + conc_nemr_spec]
        name = 'nemr_conc'
    elif met_data == True:
        output = df[df['Flight_ID'] == Flight_ID][['Age_physical_avg_min', 'PRESSURE', 'TEMPERATURE', 'RHUM', 'SZA',
                                                  'JNO2_NO_O3P', 'JHNO2_OH_NO', 'JH2O2_2OH', 'JHNO3_OH_NO2', 'JO3_O2_O1D', 'JCH2O_H_HCO', 'JCH2O_H2_CO', 'JNO3_NO_O2', 'JNO3_NO2_O3P', 
                                                  'JN2O5_NO3_NO2', 'JHNO4_HO2_NO2_UV_VISonly', 'JCH3CHO_CH3_HCO', 'JPropanal_C2H5_HCO', 'JCH3OOH_CH3O_OH', 'JMeONO2_CH3O_NO2', 'JEthONO2_CH3CH2O_NO2',
                                                  'JCH3COOONO2_CH3COOO_NO2', 'JCH3COOONO2_CH3COO_NO3', 'JMAC_Products', 'JMVK_Products', 'JAcetone_CH3CO_CH3', 'JMEK_CH3CO_CH2CH3',
                                                  'JHydroxyacetone_CH3COO_CH3', 'JHydroxyacetone_CH3CO_CH3O', 'JCHOCHO_HCO_HCO', 'JCHOCHO_H2_2CO', 'JCHOCHO_CH2O_CO', 'JCH3COCHO_CH3CO_HCO',
                                                  'J23Butanedione_Products', 'JCl2_Cl_Cl', 'JClO_Cl_O3P', 'JClNO2_Cl_NO2', 'JClONO_Cl_NO2', 'JClONO2_Cl_NO3', 'JClONO2_ClO_NO2', 'JBr2_Br_Br', 'JBrO_Br_O',
                                                  'JHOBr_OH_Br', 'JBrNO_Br_NO', 'JBrONO_Br_NO2', 'JBrONO_BrO_NO', 'JBrNO2_Br_NO2', 'JBrONO2_BrO_NO2', 'JBrONO2_Br_NO3', 'JBrCl_Br_Cl', 'JCHBr3_Products']]        
        name = 'met_data'
    # sort the data based on the pysical age
    output = output.sort_values(by="Age_physical_avg_min", ascending=True)
    
    # process missing values after sorted by physical age
    for col in output.columns:
        if col not in ['Flight_ID', 'plume_num', 'closest_fire', 'emission_pass_name', 'IsEmissionPass']:
            # assign them as float
            output[col] = output[col].astype('float')
            
            # replace negative value as 0
            output[col] = output[col].clip(lower=0)
            
            # replace 0 with nan
            output[col] = output[col].replace({0:np.nan})

            # linear regression for missing value
            output[col] = output[col].interpolate(method='linear', limit_direction='forward')
            output[col] = output[col].interpolate(method='backfill')
    
            # fill missing data with 0 back
            output[col] = output[col].replace({np.nan:0})
            
    # Round the index to two decimal places
    output.index = output.index.map(lambda x: round(x, 2))
    # Round the 'Age_physical_avg_min' column to two decimal places
    output['Age_physical_avg_min'] = output['Age_physical_avg_min'].round(2)

    # save data into csv
    output.to_csv('/glade/work/lixujin/PYTHON/SciProj/Box_modeling_analysis/F0AM_analysis_TS/WE-CAN/Model_inputs_prepared/output_data/' + Flight_ID + '_' + name + '.csv',
                  index=False)
    return output

# get matlab-like data from pandas dataframe
import scipy.io as sio

def get_F0AM_inputs(dataframe, Flight_ID, smk_conc=False, bkg_conc=False, nemr_conc=False, met_data=False):
    """
    Converts a pandas dataframe to a MATLAB-compatible format and saves it.

    Args:
        dataframe (DataFrame): The dataframe to be converted.
        Flight_ID (str): The flight ID corresponding to the data.
        smk_conc (bool): If True, processes smoke concentration data.
        bkg_conc (bool): If True, processes background concentration data.
        nemr_conc (bool): If True, processes NEMR concentration data.
        met_data (bool): If True, processes meteorological data.

    Saves:
        A .mat file containing the converted data in a specified directory.
    """
    if smk_conc == True:
        out_dir = '/glade/work/lixujin/PYTHON/SciProj/Box_modeling_analysis/F0AM_analysis_TS/WE-CAN/Model_inputs_prepared/output_data/mat/' + Flight_ID + '_smk.mat'
    elif bkg_conc == True:
         out_dir = '/glade/work/lixujin/PYTHON/SciProj/Box_modeling_analysis/F0AM_analysis_TS/WE-CAN/Model_inputs_prepared/output_data/mat/' + Flight_ID + '_bkg.mat'
    elif nemr_conc == True:
         out_dir = '/glade/work/lixujin/PYTHON/SciProj/Box_modeling_analysis/F0AM_analysis_TS/WE-CAN/Model_inputs_prepared/output_data/mat/' + Flight_ID + '_nemr.mat'
    elif met_data == True:
         out_dir = '/glade/work/lixujin/PYTHON/SciProj/Box_modeling_analysis/F0AM_analysis_TS/WE-CAN/Model_inputs_prepared/output_data/mat/' + Flight_ID + '_met.mat'

    data = {name: col.values for name, col in dataframe.items()}
    sio.savemat(out_dir, data)

def kdil(conc_smk, conc_bkg, time):
    """
    Calculates the dilution rate for smoke concentration data.

    Args:
        conc_smk (array): Array of smoke concentration values.
        conc_bkg (array): Array of background concentration values.
        time (array): Array of time values in minutes.

    Returns:
        array: Array of dilution rates for each time step.

    Note:
        If the calculated rate array is empty, returns an empty array.
    """
    # dX/dt = -kdil*(X - Xb)
    dXdt = np.diff(conc_smk)/np.diff(60*time)  # loss rate, sec

    # Check if dXdt is empty
    if dXdt.size > 0:
        dXdt = np.append(dXdt, dXdt[-1])  # extend the length to same length
    else:
        # Handle the case when dXdt is empty
        # You can choose to return an empty array, a specific value, or handle it another way
        return np.array([])

    res = -np.array(dXdt)/(np.array(conc_smk) - conc_bkg)
    return res

# %%
# Read the full data
df_full = pd.read_csv('./raw_data/NEMRs.merged.transect.lixu.V2.csv',
                  sep=',')  


#df_simplified = df_full.drop(['CO', 'Exact_mass', 'NEMR', 'Formula', 'C', 'H', 'O', 'N', 'Functional_group', 'K_OH', 'NMOG_contributor', 'In_OHR_work', 'Insturment', 'XS_ppb','LATITUDE', 'LONGITUDE', 'ALTP'], axis=1)
df_simplified = df_full.drop(['CO', 'Exact_mass', 'NEMR', 'Formula', 'C', 'H', 'O', 'N', 'Functional_group', 'K_OH', 'NMOG_contributor', 'In_OHR_work', 'Insturment', 'XS_ppb', 'ALTP'], axis=1)

# For each plume num, make it into a loop later...
standard_col = 'plume_num'  # may need to be changed...
standard_col_uq = np.unique(df_simplified[standard_col])

# drop nan in standard column, ideally it will not work
standard_col_uq = standard_col_uq[~np.isnan(standard_col_uq)] 
df_simplified = df_simplified.dropna(subset=[standard_col])


data = []
for std_col in standard_col_uq:
    #if std_col in ['137', '138', '139', '151', '152', '153', '154', '176', '178', '179']: continue # This is used to filter out Ferguson Fire in RF07
    
    # Get the data with the same std/plume number
    df_std = df_simplified[df_simplified[standard_col] == std_col]

    # suppose to have use pressure measured by PTR/CIMS
    # These values should be constant for each plume number
    try:
        Flight_ID_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['Flight_ID'])[0]
        LATITUDE_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['LATITUDE'])[0]
        LONGITUDE_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['LONGITUDE'])[0]
        plume_num_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['plume_num'])[0]
        emission_pass_name_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['emission_pass_name'])[0]
        IsEmissionPass_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['IsEmissionPass'])[0]
        closest_fire_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['closest_fire'])[0]
        Age_physical_avg_min_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['Age_physical_avg_min'])[0]
        pres_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['PRESSURE'])[0]
        temp_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['TEMPERATURE'])[0]
        RH_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['RHUM'])[0]
        SZA_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['SZA'])[0]
        JO3_O2_O1D_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.O3..O2.O.1D..'])[0]
        JNO2_NO_O3P_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.NO2..NO.O.3P..'])[0]
        JH2O2_2OH_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.H2O2..2OH.'])[0]
        JNO3_NO_O2_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.NO3..NO.O2.'])[0]
        JNO3_NO2_O3P_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.NO3..NO2.O.3P..'])[0] # only 9 photolysis in this data, confirmed
        JHNO2_OH_NO_assumption   = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.HNO2..OH.NO.'])[0]
        JHNO3_OH_NO2_assumption  = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.HNO3..OH.NO2.'])[0]
        JCH2O_H_HCO_assumption   = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH2O..H.HCO.'])[0]
        JCH2O_H2_CO_assumption   = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH2O..H2.CO.'])[0]
        
        # newly added below..
        JN2O5_NO3_NO2_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.N2O5..NO3.NO2.'])[0] # newly, added
        JHNO4_HO2_NO2_UV_VISonly_assumption   = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.HNO4..HO2.NO2.UV_VISonly..'])[0] # newly, added
        JCH3CHO_CH3_HCO_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH3CHO..CH3.HCO.'])[0]
        JPropanal_C2H5_HCO_assumption         = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.Propanal..C2H5.HCO.'])[0]
        JCH3OOH_CH3O_OH_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH3OOH..CH3O.OH.'])[0]
        JMeONO2_CH3O_NO2_assumption           = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.MeONO2..CH3O.NO2.'])[0]
        JEthONO2_CH3CH2O_NO2_assumption       = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.EthONO2..CH3CH2O.NO2.'])[0]
        JCH3COOONO2_CH3COOO_NO2_assumption    = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH3CO.OONO2...CH3CO.OO..NO2.'])[0]
        JCH3COOONO2_CH3COO_NO3_assumption     = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH3CO.OONO2...CH3CO.O..NO3.'])[0]
        JMAC_Products_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.MAC..Products.'])[0]
        JMVK_Products_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.MVK..Products.'])[0]
        JAcetone_CH3CO_CH3_assumption         = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.Acetone..CH3CO.CH3.'])[0]
        JMEK_CH3CO_CH2CH3_assumption             = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.MEK..CH3CO.CH2CH3.'])[0]
        JHydroxyacetone_CH3COO_CH3_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.Hydroxyacetone..CH3COO.CH3.'])[0]
        JHydroxyacetone_CH3CO_CH3O_assumption = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.Hydroxyacetone..CH3CO.CH3O.'])[0]
        JCHOCHO_HCO_HCO_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CHOCHO..HCO.HCO.'])[0]
        JCHOCHO_H2_2CO_assumption             = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CHOCHO..H2.2CO.'])[0]
        JCHOCHO_CH2O_CO_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CHOCHO..CH2O.CO.'])[0]
        JCH3COCHO_CH3CO_HCO_assumption        = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CH3COCHO..CH3CO.HCO.'])[0]
        J23Butanedione_Products_assumption    = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.23Butanedione..Products.'])[0]
        JCl2_Cl_Cl_assumption                 = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.Cl2..Cl.Cl.'])[0]                                                                                                                              
        JClO_Cl_O3P_assumption                = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.ClO..Cl.O.3P..'])[0]
        JClNO2_Cl_NO2_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.ClNO2..Cl.NO2.'])[0]
        JClONO_Cl_NO2_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.ClONO..Cl.NO2.'])[0]
        JClONO2_Cl_NO3_assumption             = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.ClONO2..Cl.NO3.'])[0]
        JClONO2_ClO_NO2_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.ClONO2..ClO.NO2.'])[0]
        JBr2_Br_Br_assumption                 = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.Br2..Br.Br.'])[0]
        JBrO_Br_O_assumption                  = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrO..Br.O.'])[0]
        JHOBr_OH_Br_assumption                = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.HOBr..OH.Br.'])[0]
        JBrNO_Br_NO_assumption                = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrNO..Br.NO.'])[0]
        JBrONO_Br_NO2_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrONO..Br.NO2.'])[0]
        JBrONO_BrO_NO_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrONO..BrO.NO.'])[0]
        JBrNO2_Br_NO2_assumption              = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrNO2..Br.NO2.'])[0]
        JBrONO2_BrO_NO2_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrONO2..BrO.NO2.'])[0]
        JBrONO2_Br_NO3_assumption             = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrONO2..Br.NO3.'])[0]
        JBrCl_Br_Cl_assumption                = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.BrCl..Br.Cl.'])[0]
        JCHBr3_Products_assumption            = list(df_std[df_std['species']=='m33.03341..METHANOL_CH3OH.H_cal...Corr._ppb']['j.CHBr3..Products.'])[0]
    except:
        print('This is so wrong!!!')
        exit('This is wrong')
    # get needed data
    Flight_ID = Flight_ID_assumption
    LATITUDE  = LATITUDE_assumption
    LONGITUDE = LONGITUDE_assumption
    plume_num = plume_num_assumption
    closest_fire = closest_fire_assumption
    emission_pass_name = emission_pass_name_assumption
    IsEmissionPass = IsEmissionPass_assumption
    Age_physical_avg_min = Age_physical_avg_min_assumption
    PRESSURE = pres_assumption
    TEMPERATURE = temp_assumption
    RHUM = RH_assumption
    SZA = SZA_assumption
                                                                                                                              
    JO3_O2_O1D = JO3_O2_O1D_assumption
    JNO2_NO_O3P = JNO2_NO_O3P_assumption
    JH2O2_2OH = JH2O2_2OH_assumption
    JNO3_NO_O2 = JNO3_NO_O2_assumption
    JNO3_NO2_O3P = JNO3_NO2_O3P_assumption
    JHNO2_OH_NO = JHNO2_OH_NO_assumption
    JHNO3_OH_NO2 = JHNO3_OH_NO2_assumption
    JCH2O_H_HCO = JCH2O_H_HCO_assumption
    JCH2O_H2_CO = JCH2O_H2_CO_assumption
                                                                                                                              
    # newly added
    JN2O5_NO3_NO2 = JN2O5_NO3_NO2_assumption
    JHNO4_HO2_NO2_UV_VISonly = JHNO4_HO2_NO2_UV_VISonly_assumption
    JCH3CHO_CH3_HCO = JCH3CHO_CH3_HCO_assumption
    JPropanal_C2H5_HCO = JPropanal_C2H5_HCO_assumption
    JCH3OOH_CH3O_OH = JCH3OOH_CH3O_OH_assumption
    JMeONO2_CH3O_NO2 = JMeONO2_CH3O_NO2_assumption
    JEthONO2_CH3CH2O_NO2 = JEthONO2_CH3CH2O_NO2_assumption
    JCH3COOONO2_CH3COOO_NO2 = JCH3COOONO2_CH3COOO_NO2_assumption
    JCH3COOONO2_CH3COO_NO3 = JCH3COOONO2_CH3COO_NO3_assumption
    JMAC_Products = JMAC_Products_assumption
    JMVK_Products = JMVK_Products_assumption
    JAcetone_CH3CO_CH3 = JAcetone_CH3CO_CH3_assumption
    JMEK_CH3CO_CH2CH3 = JMEK_CH3CO_CH2CH3_assumption
    JHydroxyacetone_CH3COO_CH3 = JHydroxyacetone_CH3COO_CH3_assumption
    JHydroxyacetone_CH3CO_CH3O = JHydroxyacetone_CH3CO_CH3O_assumption
    JCHOCHO_HCO_HCO = JCHOCHO_HCO_HCO_assumption
    JCHOCHO_H2_2CO = JCHOCHO_H2_2CO_assumption
    JCHOCHO_CH2O_CO = JCHOCHO_CH2O_CO_assumption
    JCH3COCHO_CH3CO_HCO = JCH3COCHO_CH3CO_HCO_assumption
    J23Butanedione_Products = J23Butanedione_Products_assumption
    JCl2_Cl_Cl = JCl2_Cl_Cl_assumption
    JClO_Cl_O3P = JClO_Cl_O3P_assumption
    JClNO2_Cl_NO2 = JClNO2_Cl_NO2_assumption
    JClONO_Cl_NO2 = JClONO_Cl_NO2_assumption
    JClONO2_Cl_NO3 = JClONO2_Cl_NO3_assumption
    JClONO2_ClO_NO2 = JClONO2_ClO_NO2_assumption
    JBr2_Br_Br = JBr2_Br_Br_assumption
    JBrO_Br_O = JBrO_Br_O_assumption
    JHOBr_OH_Br = JHOBr_OH_Br_assumption
    JBrNO_Br_NO = JBrNO_Br_NO_assumption
    JBrONO_Br_NO2 = JBrONO_Br_NO2_assumption
    JBrONO_BrO_NO = JBrONO_BrO_NO_assumption
    JBrNO2_Br_NO2 = JBrNO2_Br_NO2_assumption
    JBrONO2_BrO_NO2 = JBrONO2_BrO_NO2_assumption
    JBrONO2_Br_NO3 = JBrONO2_Br_NO3_assumption
    JBrCl_Br_Cl = JBrCl_Br_Cl_assumption
    JCHBr3_Products = JCHBr3_Products_assumption                                                                        
                                                                                                                              
    species_list = df_std['species']
    conc_smk = df_std['conc_smk']
    conc_bkg = df_std['conc_bkg']

    # make the species list into more readable format
    species_list_new = []
    for ind, spec in enumerate(species_list):
        if '...' in spec:
            if 'dimethyl_furan_C6H8O' in spec:
                spec = '2_5_dimethyl_furan_C6H8O'
            elif '1.3.cyclopentadiene_C5H6' in spec:
                spec = '1_3_cyclopentadiene_C5H6'
            else:
                spec = spec.split('.')[3] + '_PTR'
        species_list_new.append(spec)
    species_list = np.array(species_list_new)

    conc_smk_spec = ['smk_' + x for x in species_list]
    conc_bkg_spec = ['bkg_' + x for x in species_list]
    conc_nemr_spec = ['nemr_' + x for x in species_list]

    # caclulate NEMR for each species
    ind = species_list == 'CO_QCL'

    CO_ehc = conc_smk[ind] - conc_bkg[ind]
    conc_nemr = (np.array(conc_smk)-np.array(conc_bkg))/np.array(CO_ehc) * 1000
    
    column_names = np.hstack(['Flight_ID', 'plume_num', 'LATITUDE', 'LONGITUDE',
                              'closest_fire', 'emission_pass_name', 'IsEmissionPass', 'Age_physical_avg_min', 
                              'PRESSURE', 'TEMPERATURE', 'RHUM', 'SZA',
                              'JNO2_NO_O3P', 'JHNO2_OH_NO', 'JH2O2_2OH', 'JHNO3_OH_NO2', 'JO3_O2_O1D', 'JCH2O_H_HCO', 'JCH2O_H2_CO', 'JNO3_NO_O2', 'JNO3_NO2_O3P', 
                              'JN2O5_NO3_NO2', 'JHNO4_HO2_NO2_UV_VISonly', 'JCH3CHO_CH3_HCO', 'JPropanal_C2H5_HCO', 'JCH3OOH_CH3O_OH', 'JMeONO2_CH3O_NO2', 'JEthONO2_CH3CH2O_NO2',
                              'JCH3COOONO2_CH3COOO_NO2', 'JCH3COOONO2_CH3COO_NO3', 'JMAC_Products', 'JMVK_Products', 'JAcetone_CH3CO_CH3', 'JMEK_CH3CO_CH2CH3',
                              'JHydroxyacetone_CH3COO_CH3', 'JHydroxyacetone_CH3CO_CH3O', 'JCHOCHO_HCO_HCO', 'JCHOCHO_H2_2CO', 'JCHOCHO_CH2O_CO', 'JCH3COCHO_CH3CO_HCO',
                              'J23Butanedione_Products', 'JCl2_Cl_Cl', 'JClO_Cl_O3P', 'JClNO2_Cl_NO2', 'JClONO_Cl_NO2', 'JClONO2_Cl_NO3', 'JClONO2_ClO_NO2', 'JBr2_Br_Br', 'JBrO_Br_O',
                              'JHOBr_OH_Br', 'JBrNO_Br_NO', 'JBrONO_Br_NO2', 'JBrONO_BrO_NO', 'JBrNO2_Br_NO2', 'JBrONO2_BrO_NO2', 'JBrONO2_Br_NO3', 'JBrCl_Br_Cl', 'JCHBr3_Products',
                              conc_smk_spec, conc_bkg_spec, conc_nemr_spec])
    data.append(np.hstack([Flight_ID, plume_num, LATITUDE, LONGITUDE, 
                           closest_fire, emission_pass_name, IsEmissionPass, Age_physical_avg_min, 
                           PRESSURE, TEMPERATURE, RHUM, SZA,
                           JNO2_NO_O3P, JHNO2_OH_NO, JH2O2_2OH, JHNO3_OH_NO2, JO3_O2_O1D, JCH2O_H_HCO, JCH2O_H2_CO, JNO3_NO_O2, JNO3_NO2_O3P,
                           JN2O5_NO3_NO2, JHNO4_HO2_NO2_UV_VISonly, JCH3CHO_CH3_HCO, JPropanal_C2H5_HCO, JCH3OOH_CH3O_OH, JMeONO2_CH3O_NO2, JEthONO2_CH3CH2O_NO2, 
                           JCH3COOONO2_CH3COOO_NO2, JCH3COOONO2_CH3COO_NO3, JMAC_Products, JMVK_Products, JAcetone_CH3CO_CH3, JMEK_CH3CO_CH2CH3,
                           JHydroxyacetone_CH3COO_CH3, JHydroxyacetone_CH3CO_CH3O, JCHOCHO_HCO_HCO, JCHOCHO_H2_2CO, JCHOCHO_CH2O_CO, JCH3COCHO_CH3CO_HCO, 
                           J23Butanedione_Products, JCl2_Cl_Cl, JClO_Cl_O3P, JClNO2_Cl_NO2, JClONO_Cl_NO2, JClONO2_Cl_NO3, JClONO2_ClO_NO2, JBr2_Br_Br, JBrO_Br_O, 
                           JHOBr_OH_Br, JBrNO_Br_NO, JBrONO_Br_NO2, JBrONO_BrO_NO, JBrNO2_Br_NO2, JBrONO2_BrO_NO2, JBrONO2_Br_NO3, JBrCl_Br_Cl, JCHBr3_Products,
                           conc_smk, conc_bkg, conc_nemr]))

df = pd.DataFrame(np.array(data), columns = column_names) # need to make panda understand we are putting rows

# soft conversion for data type
df["Age_physical_avg_min"] = pd.to_numeric(df["Age_physical_avg_min"]).round(2)

# Sorting within each group
df = df.groupby('Flight_ID', group_keys=False).apply(lambda x: x.sort_values('Age_physical_avg_min'))

# %%
# Based on CO, check the figure, confirmed, really bad data
df = df[~(((df['Flight_ID'] == 'RF03') & (df['Age_physical_avg_min'].isin(['31.64', '108.96', '120.72', '124.72', '132.47', '136.27', '138.52']))))]
df = df[~(((df['Flight_ID'] == 'RF07') & (df['Age_physical_avg_min'].isin(['66.28', '157.77', '141.06', '170.02', '178.49']))))]
df = df[~(((df['Flight_ID'] == 'RF09') & (df['Age_physical_avg_min'].isin(['135.64','197.50', '236.04', '280.05']))))]
df[df['Flight_ID'] == 'RF07'][['Flight_ID', 'Age_physical_avg_min', 'smk_O3', 'smk_BENZENE_C6H6_PTR', 'smk_CO_QCL', 'smk_NO2', 'smk_NO']]
# Out:
#     Flight_ID  Age_physical_avg_min              smk_O3 smk_BENZENE_C6H6_PTR  \
# 116      RF07                121.49             136.815   6.8546771962346105
# 106      RF07                127.78              137.74   11.238657886487301
# 110      RF07                134.10  121.96666666666701     6.35765140373116
# 107      RF07                165.99    128.140263157895   5.6840171086170805
# 117      RF07                181.23    93.2537777777778     1.12595603921459
# 121      RF07                188.55    91.5233958333333     4.85012795313032
# 108      RF07                189.73  111.84899999999999      5.7331468387385
# 112      RF07                195.37  117.18880952381001    6.514701582867219
# 109      RF07                212.49    106.045833333333     2.05695278024725
# 118      RF07                243.56             83.6956   1.5463078872875902
# 119      RF07                276.89   99.41307692307691   3.6600343456227202
# 120      RF07                295.82   77.15115384615379     2.24879877460173
#
#              smk_CO_QCL             smk_NO2               smk_NO
# 116              3289.4             7.76243   1.3517620000000001
# 106           5894.0875              3.3706           0.39385125
# 110    3175.06666666667  2.0117416666666696             0.324395
# 107    3165.31052631579  1.2183421052631598    0.145252631578947
# 117    628.088888888889             1.15945  0.12113672222222198
# 121           2688.2125           1.2607625           0.14352375
# 108             3120.11  1.3682524999999999            0.1909305
# 112    3461.01904761905  1.6552042857142901  0.18869464285714302
# 109  1284.7833333333301   0.894525833333333  0.17163666666666696
# 118              893.64  0.9812844999999999           0.08194275
# 119    2034.27692307692    1.06886442307692   0.0803141346153846
# 120    1320.15384615385              1.0582  0.07409500000000001

# %%
# get matlab-like data from pandas for conc, bkg, and met data
Flight_IDs = np.unique(df['Flight_ID']).astype('str')

for Flight_ID in Flight_IDs:
    # conc
    df_conc = WECAN_process(df, Flight_ID=Flight_ID, smk_conc=True)    
    #df_conc = fix_PTR_isomers(df_conc, smk_conc= True, bkg_conc=False)
    get_F0AM_inputs(df_conc, Flight_ID=Flight_ID, smk_conc=True)
    
    # bkg
    df_bkg = WECAN_process(df, Flight_ID=Flight_ID, bkg_conc=True)
    #df_bkg = fix_PTR_isomers(df_bkg, smk_conc= False, bkg_conc=True)
    get_F0AM_inputs(df_bkg, Flight_ID=Flight_ID, bkg_conc=True)
 
    # nemr
    #df_nemr = WECAN_process(df, Flight_ID=Flight_ID, nemr_conc=True)
    #get_F0AM_inputs(df_nemr, Flight_ID=Flight_ID, nemr_conc=True)
    
    # met
    # add integration time into the met data
    # calcualte the integration time step
    time = np.array(df_conc['Age_physical_avg_min'])
    
    # Setting start_ind, this is only for calculating InitTime
    # If we changed the start_ind here, please make sure the F0AM used the right datapoint to inialize the model.
    start_ind = 1 if (Flight_ID == 'RF03') else 0
    
    #print(time)
    
    # intTime
    InitTime = (float(time[-1])-float(time[start_ind]))*60/len(time)

    # Any dilution (constrained by CO and Benzene) less than 0 will be removed
    kdil_CO = kdil(df_conc['smk_CO_QCL'].astype('float'), df_bkg['bkg_CO_QCL'].astype('float'), time)
    kdil_benz = kdil(df_conc['smk_BENZENE_C6H6_PTR'].astype('float'), df_bkg['bkg_BENZENE_C6H6_PTR'].astype('float'), time)
    bool_index = (kdil_CO > 0) & (kdil_benz > 0)
    kdil_values = np.hstack([kdil_CO[bool_index], kdil_benz[bool_index]])
    kdil_med = np.median(kdil_values)
    df_met = WECAN_process(df, Flight_ID=Flight_ID, met_data=True)
    df_met['Int_time'] = [InitTime]*len(time)
    


    if Flight_ID == 'RF03': df_met['kdil'] = [3.5e-4]*len(time) # these kdils are from Qiaoyun
    if Flight_ID == 'RF07': df_met['kdil'] = [0.5e-4]*len(time)
    if Flight_ID == 'RF09': df_met['kdil'] = [1.75e-4]*len(time)#*10+[1e-4]*(len(time)-10)
    
    get_F0AM_inputs(df_met, Flight_ID=Flight_ID, met_data=True)
    print('This is the flight ID: ', Flight_ID)
    print('This is the integration time for the model', InitTime)
    print('This is the median dilution constant for model', kdil_med)
# Out:
# This is the flight ID:  RF01
# This is the integration time for the model 1346.1692307692306
# This is the median dilution constant for model 0.0003580522404781156
# This is the flight ID:  RF02
# This is the integration time for the model 2496.913043478261
# This is the median dilution constant for model 0.000841727508412466
# This is the flight ID:  RF03
# This is the integration time for the model 571.7538461538461
# This is the median dilution constant for model 0.0004560801175131727
# This is the flight ID:  RF04
# This is the integration time for the model 1152.69
# This is the median dilution constant for model 0.000495321968885748
# This is the flight ID:  RF05
# This is the integration time for the model 1520.470588235294
# This is the median dilution constant for model 0.00016270695466656069
# This is the flight ID:  RF06
# This is the integration time for the model 1225.0615384615385
# This is the median dilution constant for model 0.000700264970084736
# This is the flight ID:  RF07
# This is the integration time for the model 871.65
# This is the median dilution constant for model 0.0006473967013513316
# This is the flight ID:  RF09
# This is the integration time for the model 689.0727272727273
# This is the median dilution constant for model 0.0004781723114669535
# This is the flight ID:  RF10
# This is the integration time for the model 957.1999999999999
# This is the median dilution constant for model 0.00067307533282837
# This is the flight ID:  RF11
# This is the integration time for the model 1590.4333333333332
# This is the median dilution constant for model 0.00040040795950282146
# This is the flight ID:  RF13
# This is the integration time for the model 988.32
# This is the median dilution constant for model 0.0006664622606011197
# This is the flight ID:  RF18
# This is the integration time for the model 25.500000000000043
# This is the median dilution constant for model 0.004698263763861207
# This is the flight ID:  RF19
# This is the integration time for the model 166.79999999999995
# This is the median dilution constant for model 0.0015444067880481301

# %% [markdown]
# ### Note (kdil)
# RF03: 3.5e-4 is fine but a little bit high
#
# RD07: 1e-4 seems fine
#
# RF09: 1.9/2e-4 seems okay.

# %%
list(df_met.columns)
# Out:
# ['Age_physical_avg_min',
#  'PRESSURE',
#  'TEMPERATURE',
#  'RHUM',
#  'SZA',
#  'JNO2_NO_O3P',
#  'JHNO2_OH_NO',
#  'JH2O2_2OH',
#  'JHNO3_OH_NO2',
#  'JO3_O2_O1D',
#  'JCH2O_H_HCO',
#  'JCH2O_H2_CO',
#  'JNO3_NO_O2',
#  'JNO3_NO2_O3P',
#  'JN2O5_NO3_NO2',
#  'JHNO4_HO2_NO2_UV_VISonly',
#  'JCH3CHO_CH3_HCO',
#  'JPropanal_C2H5_HCO',
#  'JCH3OOH_CH3O_OH',
#  'JMeONO2_CH3O_NO2',
#  'JEthONO2_CH3CH2O_NO2',
#  'JCH3COOONO2_CH3COOO_NO2',
#  'JCH3COOONO2_CH3COO_NO3',
#  'JMAC_Products',
#  'JMVK_Products',
#  'JAcetone_CH3CO_CH3',
#  'JMEK_CH3CO_CH2CH3',
#  'JHydroxyacetone_CH3COO_CH3',
#  'JHydroxyacetone_CH3CO_CH3O',
#  'JCHOCHO_HCO_HCO',
#  'JCHOCHO_H2_2CO',
#  'JCHOCHO_CH2O_CO',
#  'JCH3COCHO_CH3CO_HCO',
#  'J23Butanedione_Products',
#  'JCl2_Cl_Cl',
#  'JClO_Cl_O3P',
#  'JClNO2_Cl_NO2',
#  'JClONO_Cl_NO2',
#  'JClONO2_Cl_NO3',
#  'JClONO2_ClO_NO2',
#  'JBr2_Br_Br',
#  'JBrO_Br_O',
#  'JHOBr_OH_Br',
#  'JBrNO_Br_NO',
#  'JBrONO_Br_NO2',
#  'JBrONO_BrO_NO',
#  'JBrNO2_Br_NO2',
#  'JBrONO2_BrO_NO2',
#  'JBrONO2_Br_NO3',
#  'JBrCl_Br_Cl',
#  'JCHBr3_Products',
#  'Int_time']

# %%
list(df_bkg.columns)
# Out:
# ['Age_physical_avg_min',
#  'bkg_OA_AMS',
#  'bkg_Methane_PICARRO',
#  'bkg_Ethyne_AWAS',
#  'bkg_HCN_UWCIMS',
#  'bkg_HCN_PTR',
#  'bkg_HCN_TOGA',
#  'bkg_CO_QCL',
#  'bkg_ethene_C2H4_PTR',
#  'bkg_Ethene_AWAS',
#  'bkg_NO',
#  'bkg_formaldehyde_CH2O_PTR',
#  'bkg_CH2O_TOGA',
#  'bkg_Ethane_AWAS',
#  'bkg_METHANOL_CH3OH_PTR',
#  'bkg_CH3OH_TOGA',
#  'bkg_PROPYNE_C3H4_PTR',
#  'bkg_ACETONITRILE_C2H3N_PTR',
#  'bkg_CH3CN_TOGA',
#  'bkg_Acetonitrile_AWAS',
#  'bkg_propene_C3H6_PTR',
#  'bkg_Propylene_AWAS',
#  'bkg_isocyanic_acid_HNCO_PTR',
#  'bkg_ethenamine_C2H5N_PTR',
#  'bkg_CO2_PICARRO_ppb',
#  'bkg_NO2',
#  'bkg_ACETALDEHYDE_C2H4O_PTR',
#  'bkg_CH3CHO_TOGA',
#  'bkg_Acetaldehyde_AWAS',
#  'bkg_Propane_TOGA',
#  'bkg_Propane_AWAS',
#  'bkg_formamide_CH3NO_PTR',
#  'bkg_CH2O2_UWCIMS',
#  'bkg_formic_acid_CH2O2_PTR',
#  'bkg_ETHANOL_C2H6O_PTR',
#  'bkg_C2H5OH_TOGA',
#  'bkg_HONO_UWCIMS',
#  'bkg_HONO_HNO2_PTR',
#  'bkg_O3',
#  'bkg_CH3Cl_TOGA',
#  'bkg_1_buten_3_yne_C4H4_PTR',
#  'bkg_acrylonitrile_C3H3N_PTR',
#  'bkg_Acrylonitrile_TOGA',
#  'bkg_2_propynal_C3H2O_PTR',
#  'bkg_butadiene_C4H6_PTR',
#  'bkg_propane_PTR',
#  'bkg_acrolein_C3H4O_PTR',
#  'bkg_Acrolein_TOGA',
#  'bkg_1_BUTENE_PTR',
#  'bkg_iButene1Butene_TOGA',
#  'bkg_cisx2butene_AWAS',
#  'bkg_transx2butene_AWAS',
#  'bkg_x1Butene_AWAS',
#  'bkg_methyl_isocyanate_C2H3NO_PTR',
#  'bkg_propene_amine_C3H7N_PTR',
#  'bkg_glyoxal_C2H2O2_PTR',
#  'bkg_ACETONE_C3H6O_PTR',
#  'bkg_Acetone_TOGA',
#  'bkg_Propanal_TOGA',
#  'bkg_Acetone_AWAS',
#  'bkg_iButane_TOGA',
#  'bkg_nButane_TOGA',
#  'bkg_Isobutane_AWAS',
#  'bkg_N_butane_AWAS',
#  'bkg_acetamide_C2H5NO_PTR',
#  'bkg_trimethylamine_C3H9N_PTR',
#  'bkg_acetic_acid_C2H4O2_PTR',
#  'bkg_iPropanol_TOGA',
#  'bkg_nitromethane_CH3NO2_PTR',
#  'bkg_DMS_PTR',
#  'bkg_DMS_TOGA',
#  'bkg_DMS_AWAS',
#  'bkg_cyanoallene_isomers_C4H3N_PTR',
#  'bkg_1_3_cyclopentadiene_C5H6',
#  'bkg_pyrrol_C4H5N_PTR',
#  'bkg_MeAcrylonitrile_TOGA',
#  'bkg_carbon_suboxide_C3O2_PTR',
#  'bkg_FURAN_C4H4O_PTR',
#  'bkg_Furan_TOGA',
#  'bkg_ISOPRENE_C5H8_PTR',
#  'bkg_Isoprene_TOGA',
#  'bkg_Isoprene_AWAS',
#  'bkg_dihydropyrrole_C4H7N_PTR',
#  'bkg_propiolic_acid_C3H2O2_PTR',
#  'bkg_MACR_MVK_C4H6O_PTR',
#  'bkg_MAC_TOGA',
#  'bkg_MVK_TOGA',
#  'bkg_x2Butenals_TOGA',
#  'bkg_MACR_AWAS',
#  'bkg_MVK_AWAS',
#  'bkg_pentene_C5H10_PTR',
#  'bkg_Cyclopentane_AWAS',
#  'bkg_butene_amine_C4H9N_PTR',
#  'bkg_methyl_glyoxal_C3H4O2_PTR',
#  'bkg_MEK_C4H8O_PTR',
#  'bkg_Butanal_TOGA',
#  'bkg_MEK_TOGA',
#  'bkg_MEK_AWAS',
#  'bkg_iPentane_TOGA',
#  'bkg_nPentane_TOGA',
#  'bkg_Isopentane_AWAS',
#  'bkg_nPentane_AWAS',
#  'bkg_nitroethene_C2H3NO2_PTR',
#  'bkg_hydroxyacetone_C3H6O2_PTR',
#  'bkg_nitroethane_C2H5NO2_PTR',
#  'bkg_CS2_TOGA',
#  'bkg_BENZENE_C6H6_PTR',
#  'bkg_Benzene_TOGA',
#  'bkg_Benzene_CHB_AWAS',
#  'bkg_pyridine_C5H5N_PTR',
#  'bkg_2_4_cyclopentadiene_1_one_C5H4O_PTR',
#  'bkg_methyl_pyrrole_isomers_C5H7N_PTR',
#  'bkg_2_METHYLFURAN_C5H6O_PTR',
#  'bkg_x2MeFuran_TOGA',
#  'bkg_x3MeFuran_TOGA',
#  'bkg_x22Dimethylbutane_AWAS',
#  'bkg_pentanenitriles_C5H9N_PTR',
#  'bkg_CH2Cl2_TOGA',
#  'bkg_2_3H_furanone_C4H4O2_PTR',
#  'bkg_cyclopentanone_C5H8O_PTR',
#  'bkg_Cyclohexane_CHB_AWAS',
#  'bkg_x1Hexene_AWAS',
#  'bkg_HCFC22_TOGA',
#  'bkg_2_3_butanedione_C4H6O2_PTR',
#  'bkg_3_methyl_2_butanone_C5H10O_PTR',
#  'bkg_MBO_TOGA',
#  'bkg_nHexane_TOGA',
#  'bkg_x2MePentane_TOGA',
#  'bkg_x3MePentane_TOGA',
#  'bkg_Hexane_AWAS',
#  'bkg_x3Methylpentane_AWAS',
#  'bkg_pyruvic_acid_C3H4O3_PTR',
#  'bkg_methyl_propanoate_C4H8O2_PTR',
#  'bkg_nitropropanes_C3H7NO2_PTR',
#  'bkg_x24Dimethylpentane_AWAS',
#  'bkg_ethylnylpyrrole_C6H5N_PTR',
#  'bkg_TOLUENE_C7H8_PTR',
#  'bkg_Toluene_TOGA',
#  'bkg_Toluene_AWAS',
#  'bkg_3_furancarbonitrile_C5H3NO_PTR',
#  'bkg_2_methyl_pyridine_C6H7N_PTR',
#  'bkg_CH3Br_TOGA',
#  'bkg_C6H6O_UWCIMS',
#  'bkg_phenol_C6H6O_PTR',
#  'bkg_2_FURALDEHYDE_C5H4O2_PTR',
#  'bkg_2_5_dimethyl_furan_C6H8O',
#  'bkg_4_methylpentanenitrile_C6H11N_PTR',
#  'bkg_CH2ClCH2Cl_TOGA',
#  'bkg_maleic_anhydride_C4H2O3_PTR',
#  'bkg_2_furanmethanol_C5H6O2_PTR',
#  'bkg_cyclohexanone_C6H10O_PTR',
#  'bkg_Methylcyclohexane_CHB_AWAS',
#  'bkg_dihydro_furandione_C4H4O3_PTR',
#  'bkg_methyl_methacrylate_C5H8O2_PTR',
#  'bkg_3_HEXANONE_C6H12O_PTR',
#  'bkg_nHeptane_TOGA',
#  'bkg_nHeptan_CHB_AWAS',
#  'bkg_x23Dimethylpentane_AWAS',
#  'bkg_x2Methylhexane_AWAS',
#  'bkg_x3Methylhexane_AWAS',
#  'bkg_HFC134a_TOGA',
#  'bkg_acetic_anhydride_C4H6O3_PTR',
#  'bkg_benzonitrile_C7H5N_PTR',
#  'bkg_styrene_C8H8_PTR',
#  'bkg_Styrene_TOGA',
#  'bkg_iPropONO2_TOGA',
#  'bkg_nPropONO2_TOGA',
#  'bkg_vinylpyridine_C7H7N_PTR',
#  'bkg_benzaldehyde_C7H6O_PTR',
#  'bkg_C8_AROMATICS_C8H10_PTR',
#  'bkg_mpXylene_TOGA',
#  'bkg_oXylene_TOGA',
#  'bkg_Ethylbenzene_AWAS',
#  'bkg_mpXylene_AWAS',
#  'bkg_oXylene_AWAS',
#  'bkg_p_benzoquinone_C6H4O2_PTR',
#  'bkg_o_cresol_C7H8O_PTR',
#  'bkg_5_METHYLFURFURAL_C6H6O2_PTR',
#  'bkg_C3_furan_C7H10O_PTR',
#  'bkg_dihydroxy_pyridine_C5H5NO2_PTR',
#  'bkg_ClBenzene_TOGA',
#  'bkg_5_hydroxy_2_furfural_PTR',
#  'bkg_2_hydroxy_3_methyl_2_cyclopenten_1_one_C6H8O2_PTR',
#  'bkg_ethylcyclopentanone_C7H12O_PTR',
#  'bkg_nitrofuran_C4H3NO3_PTR',
#  'bkg_5_hydroxymethyl_2_3H_furanone_C5H6O3_PTR',
#  'bkg_C6_diones_C6H10O2_PTR',
#  'bkg_heptanal_C7H14O_PTR',
#  'bkg_nOctane_TOGA',
#  'bkg_x224TrimePentane_TOGA',
#  'bkg_nOctane_AWAS',
#  'bkg_x234Trimethylpentane_AWAS',
#  'bkg_x2Methylheptane_AWAS',
#  'bkg_x3Methylheptane_AWAS',
#  'bkg_HCFC141b_TOGA',
#  'bkg_2_5_dihydroxymethyl_dihydrofurfural_C5H8O3_PTR',
#  'bkg_C6_esters_C6H12O2_PTR',
#  'bkg_benzeneacetonitrile_C8H7N_PTR',
#  'bkg_CHCl3_TOGA',
#  'bkg_benzofuran_C8H6O_PTR',
#  'bkg_indane_C9H10_PTR',
#  'bkg_tolualdehyde_C8H8O_PTR',
#  'bkg_C9_AROMATICS_C9H12_PTR',
#  'bkg_Isopropylbenzene_AWAS',
#  'bkg_nPropylbenzene_AWAS',
#  'bkg_x123Trimethylbenzene_AWAS',
#  'bkg_x124Trimethylbenzene_AWAS',
#  'bkg_x135Trimethylbenzene_AWAS',
#  'bkg_x2Ethyltoluene_AWAS',
#  'bkg_x3Ethyltoluene_AWAS',
#  'bkg_x4Ethyltoluene_AWAS',
#  'bkg_salicylaldehyde_C7H6O2_PTR',
#  'bkg_C2_phenols_C8H10O_PTR',
#  'bkg_hydroxy_benzoquinone_C6H4O3_PTR',
#  'bkg_guaiacol_C7H8O2_PTR',
#  'bkg_5_hydroxymethyl_2_furfural_C6H6O3_PTR',
#  'bkg_nNonane_AWAS',
#  'bkg_CH3CCl3_TOGA',
#  'bkg_methyl_benzofuran_C9H8O_PTR',
#  'bkg_methyl_propenyl_benzene_C10H12_PTR',
#  'bkg_3_methylacetophenone_C9H10O_PTR',
#  'bkg_C10_AROMATICS_C10H14_PTR',
#  'bkg_x13Diethylbenzene_AWAS',
#  'bkg_x14Diethylbenzene_AWAS',
#  'bkg_methyl_benzoic_acid_C8H8O2_PTR',
#  'bkg_MONOTERPENES_C10H16_PTR',
#  'bkg_Camphene_TOGA',
#  'bkg_Tricyclene_TOGA',
#  'bkg_aPinene_TOGA',
#  'bkg_bPineneMyrcene_TOGA',
#  'bkg_nitrotoluene_C7H7NO2_PTR',
#  'bkg_creosol_C8H10O2_PTR',
#  'bkg_CH3I_TOGA',
#  'bkg_methyl_naphthalene_C11H10_PTR',
#  'bkg_nDecane_AWAS',
#  'bkg_levoglucosan_pyrolysis_product_C6H8O4_PTR',
#  'bkg_dimethylbenzofuran_C10H10O_PTR',
#  'bkg_estragole_C10H12O_PTR',
#  'bkg_C11_aromatics_C11H16_PTR',
#  'bkg_vinyl_guaiacol_C9H10O2_PTR',
#  'bkg_vanillin_C8H8O3_PTR',
#  'bkg_camphor_C10H16O_PTR',
#  'bkg_syringol_C8H10O3_PTR',
#  'bkg_cineole_C10H18O_PTR',
#  'bkg_1_3_dimethylnaphthalene_C12H12_PTR',
#  'bkg_decanal_C10H20O_PTR',
#  'bkg_Undecane_AWAS',
#  'bkg_CHBrCl2_TOGA',
#  'bkg_C12_aromatics_C12H18_PTR',
#  'bkg_C2Cl4_TOGA',
#  'bkg_eugenol_C10H12O2_PTR',
#  'bkg_CH2Br2_TOGA',
#  'bkg_CH2ClI_TOGA',
#  'bkg_C13_aromatics_C13H20_PTR',
#  'bkg_sesquiterpenes_C15H24_PTR',
#  'bkg_CHBr2Cl_TOGA',
#  'bkg_CHBr3_TOGA',
#  'bkg_C10H16O3_UWCIMS',
#  'bkg_C5H10O3_UWCIMS',
#  'bkg_C5H9O4N_UWCIMS',
#  'bkg_C6H10O5_UWCIMS',
#  'bkg_C9H14O4_UWCIMS',
#  'bkg_HCl_UWCIMS',
#  'bkg_HNO3_UWCIMS',
#  'bkg_PAN',
#  'bkg_PPN',
#  'bkg_SO2_UWCIMS',
#  'bkg_EtBenzene_TOGA',
#  'bkg_Propanenitrile_TOGA',
#  'bkg_iBuONO2and2BuONO2_TOGA',
#  'bkg_H_C_AMS',
#  'bkg_NO3_AMS',
#  'bkg_OM_OC_AMS',
#  'bkg_O_C_AMS']

# %%
df_conc['smk_CO_QCL']
# Out:
# 186    2353.760000
# 187    1440.033333
# Name: smk_CO_QCL, dtype: float64

# %%
list(df_conc.columns)
# Out:
# ['Age_physical_avg_min',
#  'smk_OA_AMS',
#  'smk_Methane_PICARRO',
#  'smk_Ethyne_AWAS',
#  'smk_HCN_UWCIMS',
#  'smk_HCN_PTR',
#  'smk_HCN_TOGA',
#  'smk_CO_QCL',
#  'smk_ethene_C2H4_PTR',
#  'smk_Ethene_AWAS',
#  'smk_NO',
#  'smk_formaldehyde_CH2O_PTR',
#  'smk_CH2O_TOGA',
#  'smk_Ethane_AWAS',
#  'smk_METHANOL_CH3OH_PTR',
#  'smk_CH3OH_TOGA',
#  'smk_PROPYNE_C3H4_PTR',
#  'smk_ACETONITRILE_C2H3N_PTR',
#  'smk_CH3CN_TOGA',
#  'smk_Acetonitrile_AWAS',
#  'smk_propene_C3H6_PTR',
#  'smk_Propylene_AWAS',
#  'smk_isocyanic_acid_HNCO_PTR',
#  'smk_ethenamine_C2H5N_PTR',
#  'smk_CO2_PICARRO_ppb',
#  'smk_NO2',
#  'smk_ACETALDEHYDE_C2H4O_PTR',
#  'smk_CH3CHO_TOGA',
#  'smk_Acetaldehyde_AWAS',
#  'smk_Propane_TOGA',
#  'smk_Propane_AWAS',
#  'smk_formamide_CH3NO_PTR',
#  'smk_CH2O2_UWCIMS',
#  'smk_formic_acid_CH2O2_PTR',
#  'smk_ETHANOL_C2H6O_PTR',
#  'smk_C2H5OH_TOGA',
#  'smk_HONO_UWCIMS',
#  'smk_HONO_HNO2_PTR',
#  'smk_O3',
#  'smk_CH3Cl_TOGA',
#  'smk_1_buten_3_yne_C4H4_PTR',
#  'smk_acrylonitrile_C3H3N_PTR',
#  'smk_Acrylonitrile_TOGA',
#  'smk_2_propynal_C3H2O_PTR',
#  'smk_butadiene_C4H6_PTR',
#  'smk_propane_PTR',
#  'smk_acrolein_C3H4O_PTR',
#  'smk_Acrolein_TOGA',
#  'smk_1_BUTENE_PTR',
#  'smk_iButene1Butene_TOGA',
#  'smk_cisx2butene_AWAS',
#  'smk_transx2butene_AWAS',
#  'smk_x1Butene_AWAS',
#  'smk_methyl_isocyanate_C2H3NO_PTR',
#  'smk_propene_amine_C3H7N_PTR',
#  'smk_glyoxal_C2H2O2_PTR',
#  'smk_ACETONE_C3H6O_PTR',
#  'smk_Acetone_TOGA',
#  'smk_Propanal_TOGA',
#  'smk_Acetone_AWAS',
#  'smk_iButane_TOGA',
#  'smk_nButane_TOGA',
#  'smk_Isobutane_AWAS',
#  'smk_N_butane_AWAS',
#  'smk_acetamide_C2H5NO_PTR',
#  'smk_trimethylamine_C3H9N_PTR',
#  'smk_acetic_acid_C2H4O2_PTR',
#  'smk_iPropanol_TOGA',
#  'smk_nitromethane_CH3NO2_PTR',
#  'smk_DMS_PTR',
#  'smk_DMS_TOGA',
#  'smk_DMS_AWAS',
#  'smk_cyanoallene_isomers_C4H3N_PTR',
#  'smk_1_3_cyclopentadiene_C5H6',
#  'smk_pyrrol_C4H5N_PTR',
#  'smk_MeAcrylonitrile_TOGA',
#  'smk_carbon_suboxide_C3O2_PTR',
#  'smk_FURAN_C4H4O_PTR',
#  'smk_Furan_TOGA',
#  'smk_ISOPRENE_C5H8_PTR',
#  'smk_Isoprene_TOGA',
#  'smk_Isoprene_AWAS',
#  'smk_dihydropyrrole_C4H7N_PTR',
#  'smk_propiolic_acid_C3H2O2_PTR',
#  'smk_MACR_MVK_C4H6O_PTR',
#  'smk_MAC_TOGA',
#  'smk_MVK_TOGA',
#  'smk_x2Butenals_TOGA',
#  'smk_MACR_AWAS',
#  'smk_MVK_AWAS',
#  'smk_pentene_C5H10_PTR',
#  'smk_Cyclopentane_AWAS',
#  'smk_butene_amine_C4H9N_PTR',
#  'smk_methyl_glyoxal_C3H4O2_PTR',
#  'smk_MEK_C4H8O_PTR',
#  'smk_Butanal_TOGA',
#  'smk_MEK_TOGA',
#  'smk_MEK_AWAS',
#  'smk_iPentane_TOGA',
#  'smk_nPentane_TOGA',
#  'smk_Isopentane_AWAS',
#  'smk_nPentane_AWAS',
#  'smk_nitroethene_C2H3NO2_PTR',
#  'smk_hydroxyacetone_C3H6O2_PTR',
#  'smk_nitroethane_C2H5NO2_PTR',
#  'smk_CS2_TOGA',
#  'smk_BENZENE_C6H6_PTR',
#  'smk_Benzene_TOGA',
#  'smk_Benzene_CHB_AWAS',
#  'smk_pyridine_C5H5N_PTR',
#  'smk_2_4_cyclopentadiene_1_one_C5H4O_PTR',
#  'smk_methyl_pyrrole_isomers_C5H7N_PTR',
#  'smk_2_METHYLFURAN_C5H6O_PTR',
#  'smk_x2MeFuran_TOGA',
#  'smk_x3MeFuran_TOGA',
#  'smk_x22Dimethylbutane_AWAS',
#  'smk_pentanenitriles_C5H9N_PTR',
#  'smk_CH2Cl2_TOGA',
#  'smk_2_3H_furanone_C4H4O2_PTR',
#  'smk_cyclopentanone_C5H8O_PTR',
#  'smk_Cyclohexane_CHB_AWAS',
#  'smk_x1Hexene_AWAS',
#  'smk_HCFC22_TOGA',
#  'smk_2_3_butanedione_C4H6O2_PTR',
#  'smk_3_methyl_2_butanone_C5H10O_PTR',
#  'smk_MBO_TOGA',
#  'smk_nHexane_TOGA',
#  'smk_x2MePentane_TOGA',
#  'smk_x3MePentane_TOGA',
#  'smk_Hexane_AWAS',
#  'smk_x3Methylpentane_AWAS',
#  'smk_pyruvic_acid_C3H4O3_PTR',
#  'smk_methyl_propanoate_C4H8O2_PTR',
#  'smk_nitropropanes_C3H7NO2_PTR',
#  'smk_x24Dimethylpentane_AWAS',
#  'smk_ethylnylpyrrole_C6H5N_PTR',
#  'smk_TOLUENE_C7H8_PTR',
#  'smk_Toluene_TOGA',
#  'smk_Toluene_AWAS',
#  'smk_3_furancarbonitrile_C5H3NO_PTR',
#  'smk_2_methyl_pyridine_C6H7N_PTR',
#  'smk_CH3Br_TOGA',
#  'smk_C6H6O_UWCIMS',
#  'smk_phenol_C6H6O_PTR',
#  'smk_2_FURALDEHYDE_C5H4O2_PTR',
#  'smk_2_5_dimethyl_furan_C6H8O',
#  'smk_4_methylpentanenitrile_C6H11N_PTR',
#  'smk_CH2ClCH2Cl_TOGA',
#  'smk_maleic_anhydride_C4H2O3_PTR',
#  'smk_2_furanmethanol_C5H6O2_PTR',
#  'smk_cyclohexanone_C6H10O_PTR',
#  'smk_Methylcyclohexane_CHB_AWAS',
#  'smk_dihydro_furandione_C4H4O3_PTR',
#  'smk_methyl_methacrylate_C5H8O2_PTR',
#  'smk_3_HEXANONE_C6H12O_PTR',
#  'smk_nHeptane_TOGA',
#  'smk_nHeptan_CHB_AWAS',
#  'smk_x23Dimethylpentane_AWAS',
#  'smk_x2Methylhexane_AWAS',
#  'smk_x3Methylhexane_AWAS',
#  'smk_HFC134a_TOGA',
#  'smk_acetic_anhydride_C4H6O3_PTR',
#  'smk_benzonitrile_C7H5N_PTR',
#  'smk_styrene_C8H8_PTR',
#  'smk_Styrene_TOGA',
#  'smk_iPropONO2_TOGA',
#  'smk_nPropONO2_TOGA',
#  'smk_vinylpyridine_C7H7N_PTR',
#  'smk_benzaldehyde_C7H6O_PTR',
#  'smk_C8_AROMATICS_C8H10_PTR',
#  'smk_mpXylene_TOGA',
#  'smk_oXylene_TOGA',
#  'smk_Ethylbenzene_AWAS',
#  'smk_mpXylene_AWAS',
#  'smk_oXylene_AWAS',
#  'smk_p_benzoquinone_C6H4O2_PTR',
#  'smk_o_cresol_C7H8O_PTR',
#  'smk_5_METHYLFURFURAL_C6H6O2_PTR',
#  'smk_C3_furan_C7H10O_PTR',
#  'smk_dihydroxy_pyridine_C5H5NO2_PTR',
#  'smk_ClBenzene_TOGA',
#  'smk_5_hydroxy_2_furfural_PTR',
#  'smk_2_hydroxy_3_methyl_2_cyclopenten_1_one_C6H8O2_PTR',
#  'smk_ethylcyclopentanone_C7H12O_PTR',
#  'smk_nitrofuran_C4H3NO3_PTR',
#  'smk_5_hydroxymethyl_2_3H_furanone_C5H6O3_PTR',
#  'smk_C6_diones_C6H10O2_PTR',
#  'smk_heptanal_C7H14O_PTR',
#  'smk_nOctane_TOGA',
#  'smk_x224TrimePentane_TOGA',
#  'smk_nOctane_AWAS',
#  'smk_x234Trimethylpentane_AWAS',
#  'smk_x2Methylheptane_AWAS',
#  'smk_x3Methylheptane_AWAS',
#  'smk_HCFC141b_TOGA',
#  'smk_2_5_dihydroxymethyl_dihydrofurfural_C5H8O3_PTR',
#  'smk_C6_esters_C6H12O2_PTR',
#  'smk_benzeneacetonitrile_C8H7N_PTR',
#  'smk_CHCl3_TOGA',
#  'smk_benzofuran_C8H6O_PTR',
#  'smk_indane_C9H10_PTR',
#  'smk_tolualdehyde_C8H8O_PTR',
#  'smk_C9_AROMATICS_C9H12_PTR',
#  'smk_Isopropylbenzene_AWAS',
#  'smk_nPropylbenzene_AWAS',
#  'smk_x123Trimethylbenzene_AWAS',
#  'smk_x124Trimethylbenzene_AWAS',
#  'smk_x135Trimethylbenzene_AWAS',
#  'smk_x2Ethyltoluene_AWAS',
#  'smk_x3Ethyltoluene_AWAS',
#  'smk_x4Ethyltoluene_AWAS',
#  'smk_salicylaldehyde_C7H6O2_PTR',
#  'smk_C2_phenols_C8H10O_PTR',
#  'smk_hydroxy_benzoquinone_C6H4O3_PTR',
#  'smk_guaiacol_C7H8O2_PTR',
#  'smk_5_hydroxymethyl_2_furfural_C6H6O3_PTR',
#  'smk_nNonane_AWAS',
#  'smk_CH3CCl3_TOGA',
#  'smk_methyl_benzofuran_C9H8O_PTR',
#  'smk_methyl_propenyl_benzene_C10H12_PTR',
#  'smk_3_methylacetophenone_C9H10O_PTR',
#  'smk_C10_AROMATICS_C10H14_PTR',
#  'smk_x13Diethylbenzene_AWAS',
#  'smk_x14Diethylbenzene_AWAS',
#  'smk_methyl_benzoic_acid_C8H8O2_PTR',
#  'smk_MONOTERPENES_C10H16_PTR',
#  'smk_Camphene_TOGA',
#  'smk_Tricyclene_TOGA',
#  'smk_aPinene_TOGA',
#  'smk_bPineneMyrcene_TOGA',
#  'smk_nitrotoluene_C7H7NO2_PTR',
#  'smk_creosol_C8H10O2_PTR',
#  'smk_CH3I_TOGA',
#  'smk_methyl_naphthalene_C11H10_PTR',
#  'smk_nDecane_AWAS',
#  'smk_levoglucosan_pyrolysis_product_C6H8O4_PTR',
#  'smk_dimethylbenzofuran_C10H10O_PTR',
#  'smk_estragole_C10H12O_PTR',
#  'smk_C11_aromatics_C11H16_PTR',
#  'smk_vinyl_guaiacol_C9H10O2_PTR',
#  'smk_vanillin_C8H8O3_PTR',
#  'smk_camphor_C10H16O_PTR',
#  'smk_syringol_C8H10O3_PTR',
#  'smk_cineole_C10H18O_PTR',
#  'smk_1_3_dimethylnaphthalene_C12H12_PTR',
#  'smk_decanal_C10H20O_PTR',
#  'smk_Undecane_AWAS',
#  'smk_CHBrCl2_TOGA',
#  'smk_C12_aromatics_C12H18_PTR',
#  'smk_C2Cl4_TOGA',
#  'smk_eugenol_C10H12O2_PTR',
#  'smk_CH2Br2_TOGA',
#  'smk_CH2ClI_TOGA',
#  'smk_C13_aromatics_C13H20_PTR',
#  'smk_sesquiterpenes_C15H24_PTR',
#  'smk_CHBr2Cl_TOGA',
#  'smk_CHBr3_TOGA',
#  'smk_C10H16O3_UWCIMS',
#  'smk_C5H10O3_UWCIMS',
#  'smk_C5H9O4N_UWCIMS',
#  'smk_C6H10O5_UWCIMS',
#  'smk_C9H14O4_UWCIMS',
#  'smk_HCl_UWCIMS',
#  'smk_HNO3_UWCIMS',
#  'smk_PAN',
#  'smk_PPN',
#  'smk_SO2_UWCIMS',
#  'smk_EtBenzene_TOGA',
#  'smk_Propanenitrile_TOGA',
#  'smk_iBuONO2and2BuONO2_TOGA',
#  'smk_H_C_AMS',
#  'smk_NO3_AMS',
#  'smk_OM_OC_AMS',
#  'smk_O_C_AMS']

# %%
bool_index1 = df_full['Fractional_contribution'] != '1'
bool_index2 = df_full['Fractional_contribution'].notnull()
list(np.unique(df_full[bool_index1 & bool_index2]['NMOG_contributor']))
# Out:
# ['1,3-Butadiene_0.98, 1,2-Butadiene_0.02',
#  '2,3-Butanedione_0.95, Methyl acrylate_0.05',
#  '2,5-Dimethylfuran_0.44, 2-Ethylfuran_0.1, C2-substituted furan isomers_0.46',
#  '2-Furfural (=furaldehyde)_0.95, 3-Furfural_0.05',
#  '2-Methylfuran_0.84, 3-Methylfuran_0.16',
#  '2-Methylphenol (=o-cresol)_0.5, Anisol_0.5',
#  '2-Methylpyridine_0.93, 3-Methylpyridine_0.07',
#  '3-Furancarbonitrile_0.7, 2-Furancarbonitrile_0.3',
#  '3-Methyl-2-butanone_0.43, 2-Methylbutanal, 3-Methylbutanal_0.04, 2-Pentanone_0.32, 3-Pentanone_0.21',
#  '5-Methylfurfural_0.5, Benzene diols (=catechol, resorcinol)_0.5',
#  'Acetic acid_0.67, glycolaldehyde (=hydroxyacetaldehyde)_0.33, Methyl formate_0',
#  'Acetone_0.83, Propanal_0.17',
#  'C2 Phenols_0.5, Methyl anisol_0.5',
#  'C6 Diones_0.46, C6 1-DBE esters_0.54',
#  'Camphene_0.38, a-Pinene_0.33, b-Pinene + Myrcene_0.21, Tricyclene_0.07',
#  'Camphor_0.3, Oxygenated monoterpenes_0.7',
#  'Cineole, Other oxygenated monoterpenes_0',
#  'Cyclopentanone_0.33, 3-Methyl-3-buten-2-one_0.67',
#  'Dihydropyrrole_0.39, Butanenitriles_0.61',
#  'Dihydroxy pyridine_0.5, Methyl maleimide_0.5',
#  'Ethyl benzene_0.36, (m, p)-Xylenes_0.46, o-Xylene_0.18',
#  'Heptanal_0.63, Heptanone_0.13, 2,4-Dimethyl-3-pentanone_0.24',
#  'Hexanones_0.53, Hexanal_0.47',
#  'Hydroxyacetone_0.51, Methyl acetate_0.35, Ethyl formate_0.14',
#  'Indane_0.13, Methylstyrenes_0.84, Propenylbenzenes_0.03',
#  'Methyl ethyl ketone_0.85, Butanal_0.01, 2-Methylpropanal_0.14',
#  'Methyl isocyanate_0.5, Hydroxyacetonitrile_0.5',
#  'Methyl vinyl ketone_0.6, Methacrolein_0.28, 2-Butenal (=crotonaldehyde)_0.13',
#  'Methylcyclopentanone, Cyclohexanone_0.26, C6H10O ketones_0.74',
#  'Methylpropenylbenzenes,  Butenylbenzenes_0.5, Ethyl styrenes_0.5',
#  'Methylpyrroles_0.33, Pentenenitriles_0.67',
#  'Propyne_0.75, 1,2-Propadiene_0.25',
#  'Pyridine_0.44, Pentadienenitriles_0.56',
#  'Pyrrole_0.57, Butenenitrile isomers_0.43',
#  'Pyruvaldehyde (=methyl glyoxal)_0.5, Acrylic acid_0.5']
